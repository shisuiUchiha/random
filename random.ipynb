# %%
# what to do today ? Let's pick a data api and try to make some sense of the data

# %%
import random
import requests
import geopy
from geopy.geocoders import Nominatim
import pandas as pd

# %%
class fetch_lat_lang():
    
    def __init__(self, location):
        self.location = location        
    
    @classmethod
    def get_lat_lan(self, location):
        geopy.geocoders.options.default_user_agent = 'my_app/2'
        geolocator = Nominatim()
        data = geolocator.geocode(location)
        lat = data.latitude
        lon = data.longitude
        return (lat,lon)
    
    @classmethod
    def calc_distance(self,row,u_lat,u_lon):
        from geopy.distance import great_circle
        place1 = (u_lat, u_lon)
        place2 = (row.lat, row.lon)
        return great_circle(place1, place2).miles

    
    @classmethod
    def get_hospitals(self, location):
        (lat, lon) = self.get_lat_lan(location)
        api_call = f"https://bhuvan-app1.nrsc.gov.in/api/api_proximity/curl_hos_pos_prox.php?theme=hospital&lat={lat}&lon={lon}&buffer=3000&token=8cff2f2ae91f69d859e5de5f3cecf6ab794de201"
        df = requests.get(api_call)
        df = pd.DataFrame(df.json())
        df = df[["lat","lon","facilityname","facilityaddress","divison","facilityphone"]]
        df["distance"] = df.apply(lambda row: self.calc_distance(row,lat,lon), axis = 1)
        return df

# %%
a = fetch_lat_lang("Gajuwaka")
df = a.get_hospitals(a.location)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[71], line 2
#       1 a = fetch_lat_lang("Gajuwaka")
# ----> 2 df = a.get_hospitals(a.location)
#
# Cell In[70], line 30, in fetch_lat_lang.get_hospitals(self, location)
#      28 df = pd.DataFrame(df.json())
#      29 df = df[["lat","lon","facilityname","facilityaddress","divison","facilityphone"]]
# ---> 30 df["distance"] = df.apply(lambda row: calc_distance(row,lat,lon), axis = 1)
#      31 return df
#
# File ~/Desktop/random_shit/random_env/lib/python3.13/site-packages/pandas/core/frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File ~/Desktop/random_shit/random_env/lib/python3.13/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~/Desktop/random_shit/random_env/lib/python3.13/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~/Desktop/random_shit/random_env/lib/python3.13/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[70], line 30, in fetch_lat_lang.get_hospitals.<locals>.<lambda>(row)
#      28 df = pd.DataFrame(df.json())
#      29 df = df[["lat","lon","facilityname","facilityaddress","divison","facilityphone"]]
# ---> 30 df["distance"] = df.apply(lambda row: calc_distance(row,lat,lon), axis = 1)
#      31 return df
#
# NameError: name 'calc_distance' is not defined

# %%
df
# Out:
#              lat          lon                            facilityname  \
# 0     83.1937933     17.68012          Gajuwaka Primary Health Center
# 1     83.2331416    17.689905      Sriharipuram - Urban Health Center
# 2    83.19720075  17.68255817  Gajuwaka Hospitals Pvt Ltd Rk Hospital
# 3    83.20363006  17.68678829                        Padmaja Hospital
# 4      83.210566   17.6861619           MANVITHA MEDICALS AND GENERAL
# ..           ...          ...                                     ...
# 164   83.2078233   17.6840216                        Lalitha Medicals
# 165   83.2140617   17.6610354             Vingas Industries Pvt. Ltd
# 166   83.1898511   17.6840281                  Inox Air Products Ltd
# 167    83.210125   17.6853233                         Varuna medicals
# 168   83.2077773   17.6688342      ADITYA MEDICALS AND GENERAL STORES
#
#                                        facilityaddress        divison  \
# 0                                       China Gantyada  Visakhapatnam
# 1                                         Sriharipuram  Visakhapatnam
# 2                                        Chinagantyada  Visakhapatnam
# 3                                             Gajuwaka  Visakhapatnam
# 4    D.NO9-7-289 C/O HARSHITHA PREMISES BEHID SNEHA...  Visakhapatnam
# ..                                                 ...            ...
# 164       10-5-74 Kailash nagar Gajuwaka Visakhapatnam  Visakhapatnam
# 165  plot no.93. 94. AIE.  Pedagantyada.  Gajuwaka....  Visakhapatnam
# 166        plot no.D-92.IDA.  Autonagar. Visakapatnam   Visakhapatnam
# 167           9-153/1 main road gajuwaka Visakhapatnam  Visakhapatnam
# 168     DO.NO.22-91-1 B.C ROAD DAYALNAGAR PEDAGANTYADA  Visakhapatnam
#
#             timing facilityphone
# 0             None    9247633173
# 1             None    7386792719
# 2             None   08912517081
# 3             None   08912515648
# 4    8:00-23:00hrs    9966996151
# ..             ...           ...
# 164  8:00-23:00hrs    9848675990
# 165           None    9849156506
# 166           None   08912517415
# 167  8:00-23:00hrs    9642561516
# 168  8:00-23:00hrs    8520909497
#
# [169 rows x 7 columns]
